# %% [markdown]
# ## Graded Lab: Reflection in a Research Agent
#
# In this graded lab, you’ll implement a simple **agentic workflow** designed to simulate reflective thinking in a writing task. This is one building block of a more complex research agent that will be constructed throughout the course.
#
# ### Objective
#
# Build a three-step workflow where an LLM writes an essay draft, critiques it, and rewrites it.
#
# * **Step 1 – Drafting:** Call the LLM to generate an initial draft of an essay based on a simple prompt.
# * **Step 2 – Reflection:** Reflect on the draft using a reasoning step. (Optionally, this can be done with a different model.)
# * **Step 3 – Revision:** Apply the feedback from the reflection to generate a revised version of the essay.

# %% [markdown]
# ---
# <a name='submission'></a>
#
# <h4 style="color:green; font-weight:bold;">TIPS FOR SUCCESSFUL GRADING OF YOUR ASSIGNMENT:</h4>
#
# * All cells are frozen except for the ones where you need to write your solution code or when explicitly mentioned you can interact with it.
#
# * In each exercise cell, look for comments `### START CODE HERE ###` and `### END CODE HERE ###`. These show you where to write the solution code. **Do not add or change any code that is outside these comments**.
#
# * You can add new cells to experiment but these will be omitted by the grader, so don't rely on newly created cells to host your solution code, use the provided places for this.
#
# * Avoid using global variables unless you absolutely have to. The grader tests your code in an isolated environment without running all cells from the top. As a result, global variables may be unavailable when scoring your submission. Global variables that are meant to be used will be defined in UPPERCASE.
#
# * To submit your notebook for grading, first save it by clicking the 💾 icon on the top left of the page and then click on the <span style="background-color: red; color: white; padding: 3px 5px; font-size: 16px; border-radius: 5px;">Submit assignment</span> button on the top right of the page.
# ---

# %% [markdown]
# Before interacting with the language models, we initialize the `aisuite` client. This setup loads environment variables (e.g., API keys) from a `.env` file to securely authenticate with backend services. The `ai.Client()` instance will be used to make all model calls throughout this workflow.

# %%
from dotenv import load_dotenv

load_dotenv()

import aisuite as ai

# Define the client. You can use this variable inside your graded functions!
CLIENT = ai.Client()

# %%
import unittests

# %% [markdown]
# ## Exercise 1: `generate_draft` Function
#
# **Objective**:
# Write a function called `generate_draft` that takes in a string topic and uses a language model to generate a complete draft essay.
#
# **Inputs**:
#
# * `topic` (str): The essay topic.
# * `model` (str, optional): The model identifier to use. Defaults to `"openai:gpt-4o"`.
#
# **Output**:
#
# * A string representing the full draft of the essay.
#
# The setup for calling the LLM using the aisuite library is already provided. Focus on crafting the prompt content. You can reference this setup in later exercises to understand how to interact with the library effectively.

# %%
# GRADED FUNCTION: generate_draft

def generate_draft(topic: str, model: str = "openai:gpt-4o") -> str: 
    
    ### START CODE HERE ###

    # Define your prompt here. A multi-line f-string is typically used for this.
    prompt = f"""
    You are a helpful writing assistant.
    Write a clear, well‑structured essay (≈400–600 words) on the topic: "{topic}".
    Requirements:
    - Start with an engaging introduction and a precise thesis statement.
    - Provide 2–3 body paragraphs with concrete evidence or examples.
    - Use logical transitions; keep sentences concise.
    - End with a conclusion that revisits the thesis and offers a crisp takeaway.
    - Audience: educated general reader; tone: professional and accessible.
    Return only the essay text—no headings, bullet lists, or commentary.
    """.strip()
    
    ### END CODE HERE ###
    
    # Get a response from the LLM by creating a chat with the client.
    response = CLIENT.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=1.0,
    )

    return response.choices[0].message.content

# %% [markdown]
# Run the following cell to check your code is working correctly:

# %%
# Test your code!
unittests.test_generate_draft(generate_draft)
# Out:
#  All tests passed!

# %% [markdown]
# ## Exercise 2: `reflect_on_draft` Function
#
# **Objective**:
# Write a function called `reflect_on_draft` that takes a previously generated essay draft and uses a language model to provide constructive feedback.
#
# **Inputs**:
#
# * `draft` (str): The essay text to reflect on.
# * `model` (str, optional): The model identifier to use. Defaults to `"openai:o4-mini"`.
#
# **Output**:
#
# * A string with feedback in paragraph form.
#
# **Requirements**:
#
# * The feedback should be critical but constructive.
# * It should address issues such as structure, clarity, strength of argument, and writing style.
# * The function should send the draft to the model and return its response.
#
# You do **not** need to rewrite the essay at this step—just analyze and reflect on it.

# %%
# GRADED FUNCTION: reflect_on_draft

def reflect_on_draft(draft: str, model: str = "openai:o4-mini") -> str:

    ### START CODE HERE ###

    # Define your prompt here. A multi-line f-string is typically used for this.
    prompt = prompt = f"""
    You are an expert writing coach. Read the draft below and provide
    actionable, concise feedback that focuses on:
    1) clarity and structure, 
    2) strength of argument and evidence,
    3) style, tone, and coherence, 
    4) concrete revision suggestions.
    Return your feedback as short paragraphs with numbered points.
    Draft:
    ---
    {draft}
    ---
    """.strip()
    

    ### END CODE HERE ###

    # Get a response from the LLM by creating a chat with the client.
    response = CLIENT.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=1.0,
    )

    return response.choices[0].message.content

# %%
# Test your code!
unittests.test_reflect_on_draft(reflect_on_draft)
# Out:
#  All tests passed!

# %% [markdown]
# ## Exercise 3: `revise_draft` Function
#
# **Objective**:
# Implement a function called `revise_draft` that improves a given essay draft based on feedback from a reflection step.
#
# **Inputs**:
#
# * `original_draft` (str): The initial version of the essay.
# * `reflection` (str): Constructive feedback or critique on the draft.
# * `model` (str, optional): The model identifier to use. Defaults to `"openai:gpt-4o"`.
#
# **Output**:
#
# * A string containing the revised and improved essay.
#
# **Requirements**:
#
# * The revised draft should address the issues mentioned in the feedback.
# * It should improve clarity, coherence, argument strength, and overall flow.
# * The function should use the feedback to guide the revision, and return only the final revised essay.
#
# In this final exercise, you'll also need to manage the call to the LLM using the CLIENT, as you've practiced in previous exercises.

# %%
# GRADED FUNCTION: revise_draft

def revise_draft(original_draft: str, reflection: str, model: str = "openai:gpt-4o") -> str:

    ### START CODE HERE ###

    # Define your prompt here. A multi-line f-string is typically used for this.
    prompt = f"""
    You are an expert editor. Revise the original draft using the feedback.
    Goals:
    - Address every issue mentioned in the feedback.
    - Improve clarity, structure, logic, and flow.
    - Preserve the author’s core ideas; do not invent facts.
    - Keep length around the original (±20%).
    Return only the revised essay.
    Original draft:
    ---
    {original_draft}
    ---
    Feedback:
    ---
    {reflection}
    ---
    """.strip()

    # Get a response from the LLM by creating a chat with the client.
    response = CLIENT.chat.completions.create(
        model=model,
        messages=[
        {"role": "system", "content": "You are a careful, precise writing and editing assistant."},
        {"role": "user", "content": prompt},
        ],
    )

    

    ### END CODE HERE ###

    return response.choices[0].message.content

# %%
# Test your code!
unittests.test_revise_draft(revise_draft)
# Out:
#  All tests passed!

# %% [markdown]
# ### 🧪 Test the Reflective Writing Workflow
#
# Use the functions you implemented to simulate the complete writing workflow:
#
# 1. **Generate a draft** in response to the essay prompt.
# 2. **Reflect** on the draft to identify improvements.
# 3. **Revise** the draft using the feedback.
#
# Observe the outputs of each step. You do **not** need to modify the outputs — just verify that the workflow runs as expected and each component returns a valid string.

# %%
essay_prompt = "Should social media platforms be regulated by the government?"

# Agent 1 – Draft
draft = generate_draft(essay_prompt)
print("📝 Draft:\n")
print(draft)

# Agent 2 – Reflection
feedback = reflect_on_draft(draft)
print("\n🧠 Feedback:\n")
print(feedback)

# Agent 3 – Revision
revised = revise_draft(draft, feedback)
print("\n✍️ Revised:\n")
print(revised)
# Out:
# 📝 Draft:
#
# In an era where social media pervades virtually every aspect of daily life, the question of whether these platforms should be regulated by the government has become a topic of significant debate. Social media has revolutionized communication, democratizing the exchange of information and enabling global connectivity. However, it has also given rise to issues such as misinformation, privacy invasion, and hate speech, making the call for regulation more urgent. This essay contends that social media platforms should indeed be regulated by the government to ensure the protection of users' rights, maintain public safety, and preserve democratic processes.
#
# One compelling reason for governmental regulation of social media platforms is the need to protect users' rights, particularly with respect to privacy. Social media companies collect vast amounts of personal data, from basic demographic information to detailed insights into users’ behaviors and preferences. The misuse of this data, as evidenced by the Cambridge Analytica scandal in which user data was harvested without consent to influence political campaigns, demonstrates a stark violation of privacy rights. Government regulation could enforce stricter data protection laws, ensuring that companies not only handle user data responsibly but also remain transparent about their data collection practices. By imposing clear guidelines and penalties for violations, regulation can safeguard personal information against exploitation.
#
# Beyond privacy concerns, regulation is necessary to address the spread of misinformation and harmful content, which can have dire consequences on public safety. Social media platforms, with their algorithms designed for engagement rather than accuracy, can amplify false information, leading to real-world consequences such as panic, violence, or undermining trust in public institutions. An alarming example is the misinformation surrounding the COVID-19 pandemic, which contributed to vaccine hesitancy and, consequently, hindered public health efforts. Regulation could mandate platforms to implement rigorous content verification processes and remove content that poses threats to public safety. Such oversight would not only curb the spread of falsehoods but also foster a more informed and healthy online environment.
#
# Furthermore, regulating social media is crucial to protecting democratic processes, which are increasingly susceptible to manipulation in the digital age. Influencing public opinion through bot accounts, foreign interference, and micro-targeted political ads threaten the integrity of democratic elections. The 2016 U.S. Presidential Election serves as a stark reminder of how unregulated social media can be exploited to sway political outcomes. Governments can establish regulations that demand transparency in political advertising and take measures to eliminate automated and deceptive practices. By doing so, they can help ensure fairer electoral processes and protect the cornerstone of democracy.
#
# In conclusion, while social media offers tremendous benefits, its unregulated nature poses significant risks that necessitate governmental intervention. By regulating these platforms, governments can protect users’ rights to privacy, enhance public safety by curbing misinformation, and safeguard democratic processes from manipulation. It is imperative that such regulations strike a balance between maintaining freedom of expression and protecting the collective good, ultimately fostering a digital environment that upholds the same values and rights we cherish offline. As society continues to navigate the challenges presented by digital communication, responsible regulation will be crucial in shaping a safer and more equitable social media landscape for all.
#
# 🧠 Feedback:
#
# 1. Clarity and Structure
# Your essay follows a clear problem–solution pattern, but the introduction could state your thesis more explicitly—e.g., “This essay argues for government regulation of social media to protect privacy, public safety, and democracy.” Ensure each body paragraph opens with a strong topic sentence that previews its specific focus (privacy, misinformation, democracy) and ends with a transition to the next point.
#
# 2. Strength of Argument and Evidence
# You cite vivid examples (Cambridge Analytica, COVID-19 misinformation, 2016 election interference), which is excellent. To bolster credibility, briefly mention the scale of these problems (e.g., “over 87 million users affected”) and reference reputable studies or reports. Anticipate a counterargument—such as free-speech concerns—and rebut it to show you’ve engaged opposing views.
#
# 3. Style, Tone, and Coherence
# The tone is appropriately formal and persuasive, but beware of repetitive phrasing (“government regulation could…” appears in each paragraph). Vary your wording—use “state oversight,” “legal safeguards,” or “regulatory frameworks.” Check for passive constructions (“has been harvested”) and convert some to active voice (“Cambridge Analytica harvested…”).
#
# 4. Concrete Revision Suggestions
# – Revise the intro to include a roadmap sentence: “I will discuss regulation’s role in privacy protection, stopping misinformation, and preserving fair elections.”
# – In each body paragraph, add one statistic or study citation and close with a sentence linking back to your thesis.
# – Insert a brief counterargument paragraph after the second body section, then rebut it.
# – Tighten the conclusion by trimming generalities (“tremendous benefits”) and restating how balanced regulation upholds offline values online.
#
# ✍️ Revised:
#
# In an era where social media pervades virtually every aspect of daily life, the question of governmental regulation of these platforms has sparked significant debate. Social media has revolutionized communication by democratizing the exchange of information and enabling global connectivity. However, it has also contributed to issues such as misinformation, privacy invasion, and hate speech. This essay argues for government regulation of social media to protect privacy, public safety, and democracy. I will discuss regulation’s role in privacy protection, stopping misinformation, and preserving fair elections.
#
# One compelling reason for the regulation is the need to protect users' privacy rights. Social media companies collect vast amounts of personal data, from basic demographic information to detailed insights into users’ behaviors and preferences. The Cambridge Analytica scandal, in which over 87 million users' data was harvested without consent to influence political campaigns, starkly illustrates privacy violations. Legal safeguards could enforce stricter data protection laws, ensuring that companies handle user data responsibly and remain transparent about their data collection practices. By imposing clear guidelines and penalties for violations, regulatory frameworks can safeguard personal information against exploitation, linking back to the thesis on privacy protection.
#
# Regulation is also necessary to counteract the spread of misinformation and harmful content. Social media platforms, with algorithms designed for engagement rather than accuracy, often amplify false information, leading to real-world consequences such as panic and violence. For instance, misinformation about the COVID-19 pandemic significantly contributed to vaccine hesitancy, undermining public health efforts. State oversight could require platforms to implement robust content verification processes and remove dangerous content, thus enhancing public safety. Such measures would foster a more informed and safe online environment, aligning with the broader goal of protecting public safety outlined in the thesis.
#
# While advocating for regulation, one must consider the counterargument regarding free-speech concerns. Critics argue that government oversight could infringe on individuals’ rights to express themselves freely. However, regulations can be designed to focus on false and harmful content without limiting legitimate discourse. Legal expertise and careful guidelines can ensure that the right balance is struck, protecting freedom of speech while maintaining public order.
#
# Finally, regulating social media is crucial to protecting democratic processes vulnerable to digital manipulation. The 2016 U.S. Presidential Election highlighted how unregulated social media can be exploited to sway political outcomes, through foreign interference and micro-targeted political ads. Governments can establish regulations that demand transparency in political advertising and eliminate automated and deceptive practices, thus preserving fair elections. Such steps extend the rationale of the essay to safeguarding democracy from digital manipulations.
#
# In conclusion, while social media has transformed communication, its unregulated nature poses significant risks that necessitate governmental intervention. Regulating these platforms can protect users’ privacy rights, curb misinformation to enhance public safety, and safeguard democratic processes. Balanced regulation is crucial, upholding offline values such as privacy, safety, and democracy, online in today’s digital landscape. Responsible regulation will play a pivotal role in shaping a safer and more equitable social media environment for all.

# %% [markdown]
# To better visualize the output of each step in the reflective writing workflow, we use a utility function called `show_output`. This function displays the results of each stage (drafting, reflection, and revision) in styled boxes with custom background and text colors, making it easier to compare and understand the progression of the essay.

# %%
from utils import show_output

essay_prompt = "Should social media platforms be regulated by the government?"

show_output("Step 1 – Draft", draft, background="#fff8dc", text_color="#333333")
show_output("Step 2 – Reflection", feedback, background="#e0f7fa", text_color="#222222")
show_output("Step 3 – Revision", revised, background="#f3e5f5", text_color="#222222")
# Out:
#     <div style="
#         border: 1px solid #ccc;
#         border-radius: 10px;
#         padding: 15px;
#         margin-bottom: 15px;
#         background-color: #fff8dc;
#         color: #333333;
#     ">
#         <h3 style="margin-top: 0;">Step 1 – Draft</h3>
#         <pre style="
#             white-space: pre-wrap;
#             font-family: monospace;
#             font-size: 14px;
#         ">In an era where social media pervades virtually every aspect of daily life, the question of whether these platforms should be regulated by the government has become a topic of significant debate. Social media has revolutionized communication, democratizing the exchange of information and enabling global connectivity. However, it has also given rise to issues such as misinformation, privacy invasion, and hate speech, making the call for regulation more urgent. This essay contends that social media platforms should indeed be regulated by the government to ensure the protection of users' rights, maintain public safety, and preserve democratic processes.
#
# One compelling reason for governmental regulation of social media platforms is the need to protect users' rights, particularly with respect to privacy. Social media companies collect vast amounts of personal data, from basic demographic information to detailed insights into users’ behaviors and preferences. The misuse of this data, as evidenced by the Cambridge Analytica scandal in which user data was harvested without consent to influence political campaigns, demonstrates a stark violation of privacy rights. Government regulation could enforce stricter data protection laws, ensuring that companies not only handle user data responsibly but also remain transparent about their data collection practices. By imposing clear guidelines and penalties for violations, regulation can safeguard personal information against exploitation.
#
# Beyond privacy concerns, regulation is necessary to address the spread of misinformation and harmful content, which can have dire consequences on public safety. Social media platforms, with their algorithms designed for engagement rather than accuracy, can amplify false information, leading to real-world consequences such as panic, violence, or undermining trust in public institutions. An alarming example is the misinformation surrounding the COVID-19 pandemic, which contributed to vaccine hesitancy and, consequently, hindered public health efforts. Regulation could mandate platforms to implement rigorous content verification processes and remove content that poses threats to public safety. Such oversight would not only curb the spread of falsehoods but also foster a more informed and healthy online environment.
#
# Furthermore, regulating social media is crucial to protecting democratic processes, which are increasingly susceptible to manipulation in the digital age. Influencing public opinion through bot accounts, foreign interference, and micro-targeted political ads threaten the integrity of democratic elections. The 2016 U.S. Presidential Election serves as a stark reminder of how unregulated social media can be exploited to sway political outcomes. Governments can establish regulations that demand transparency in political advertising and take measures to eliminate automated and deceptive practices. By doing so, they can help ensure fairer electoral processes and protect the cornerstone of democracy.
#
# In conclusion, while social media offers tremendous benefits, its unregulated nature poses significant risks that necessitate governmental intervention. By regulating these platforms, governments can protect users’ rights to privacy, enhance public safety by curbing misinformation, and safeguard democratic processes from manipulation. It is imperative that such regulations strike a balance between maintaining freedom of expression and protecting the collective good, ultimately fostering a digital environment that upholds the same values and rights we cherish offline. As society continues to navigate the challenges presented by digital communication, responsible regulation will be crucial in shaping a safer and more equitable social media landscape for all.</pre>
#     </div>
#     <div style="
#         border: 1px solid #ccc;
#         border-radius: 10px;
#         padding: 15px;
#         margin-bottom: 15px;
#         background-color: #e0f7fa;
#         color: #222222;
#     ">
#         <h3 style="margin-top: 0;">Step 2 – Reflection</h3>
#         <pre style="
#             white-space: pre-wrap;
#             font-family: monospace;
#             font-size: 14px;
#         ">1. Clarity and Structure
# Your essay follows a clear problem–solution pattern, but the introduction could state your thesis more explicitly—e.g., “This essay argues for government regulation of social media to protect privacy, public safety, and democracy.” Ensure each body paragraph opens with a strong topic sentence that previews its specific focus (privacy, misinformation, democracy) and ends with a transition to the next point.
#
# 2. Strength of Argument and Evidence
# You cite vivid examples (Cambridge Analytica, COVID-19 misinformation, 2016 election interference), which is excellent. To bolster credibility, briefly mention the scale of these problems (e.g., “over 87 million users affected”) and reference reputable studies or reports. Anticipate a counterargument—such as free-speech concerns—and rebut it to show you’ve engaged opposing views.
#
# 3. Style, Tone, and Coherence
# The tone is appropriately formal and persuasive, but beware of repetitive phrasing (“government regulation could…” appears in each paragraph). Vary your wording—use “state oversight,” “legal safeguards,” or “regulatory frameworks.” Check for passive constructions (“has been harvested”) and convert some to active voice (“Cambridge Analytica harvested…”).
#
# 4. Concrete Revision Suggestions
# – Revise the intro to include a roadmap sentence: “I will discuss regulation’s role in privacy protection, stopping misinformation, and preserving fair elections.”
# – In each body paragraph, add one statistic or study citation and close with a sentence linking back to your thesis.
# – Insert a brief counterargument paragraph after the second body section, then rebut it.
# – Tighten the conclusion by trimming generalities (“tremendous benefits”) and restating how balanced regulation upholds offline values online.</pre>
#     </div>
#     <div style="
#         border: 1px solid #ccc;
#         border-radius: 10px;
#         padding: 15px;
#         margin-bottom: 15px;
#         background-color: #f3e5f5;
#         color: #222222;
#     ">
#         <h3 style="margin-top: 0;">Step 3 – Revision</h3>
#         <pre style="
#             white-space: pre-wrap;
#             font-family: monospace;
#             font-size: 14px;
#         ">In an era where social media pervades virtually every aspect of daily life, the question of governmental regulation of these platforms has sparked significant debate. Social media has revolutionized communication by democratizing the exchange of information and enabling global connectivity. However, it has also contributed to issues such as misinformation, privacy invasion, and hate speech. This essay argues for government regulation of social media to protect privacy, public safety, and democracy. I will discuss regulation’s role in privacy protection, stopping misinformation, and preserving fair elections.
#
# One compelling reason for the regulation is the need to protect users' privacy rights. Social media companies collect vast amounts of personal data, from basic demographic information to detailed insights into users’ behaviors and preferences. The Cambridge Analytica scandal, in which over 87 million users' data was harvested without consent to influence political campaigns, starkly illustrates privacy violations. Legal safeguards could enforce stricter data protection laws, ensuring that companies handle user data responsibly and remain transparent about their data collection practices. By imposing clear guidelines and penalties for violations, regulatory frameworks can safeguard personal information against exploitation, linking back to the thesis on privacy protection.
#
# Regulation is also necessary to counteract the spread of misinformation and harmful content. Social media platforms, with algorithms designed for engagement rather than accuracy, often amplify false information, leading to real-world consequences such as panic and violence. For instance, misinformation about the COVID-19 pandemic significantly contributed to vaccine hesitancy, undermining public health efforts. State oversight could require platforms to implement robust content verification processes and remove dangerous content, thus enhancing public safety. Such measures would foster a more informed and safe online environment, aligning with the broader goal of protecting public safety outlined in the thesis.
#
# While advocating for regulation, one must consider the counterargument regarding free-speech concerns. Critics argue that government oversight could infringe on individuals’ rights to express themselves freely. However, regulations can be designed to focus on false and harmful content without limiting legitimate discourse. Legal expertise and careful guidelines can ensure that the right balance is struck, protecting freedom of speech while maintaining public order.
#
# Finally, regulating social media is crucial to protecting democratic processes vulnerable to digital manipulation. The 2016 U.S. Presidential Election highlighted how unregulated social media can be exploited to sway political outcomes, through foreign interference and micro-targeted political ads. Governments can establish regulations that demand transparency in political advertising and eliminate automated and deceptive practices, thus preserving fair elections. Such steps extend the rationale of the essay to safeguarding democracy from digital manipulations.
#
# In conclusion, while social media has transformed communication, its unregulated nature poses significant risks that necessitate governmental intervention. Regulating these platforms can protect users’ privacy rights, curb misinformation to enhance public safety, and safeguard democratic processes. Balanced regulation is crucial, upholding offline values such as privacy, safety, and democracy, online in today’s digital landscape. Responsible regulation will play a pivotal role in shaping a safer and more equitable social media environment for all.</pre>
#     </div>

# %% [markdown]
# ## Check grading feedback
#
# If you have collapsed the right panel to have more screen space for your code, as shown below:
#
# <img src="./images/collapsed.png" alt="Collapsed Image" width="800" height="400"/>
#
# You can click on the left-facing arrow button (highlighted in red) to view feedback for your submission after submitting it for grading. Once expanded, it should display like this:
#
# <img src="./images/expanded.png" alt="Expanded Image" width="800" height="400"/>
